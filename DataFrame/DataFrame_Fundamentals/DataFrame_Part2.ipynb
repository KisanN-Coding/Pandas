# %% [markdown]
# ## **Important DataFrame Functions**

# %%
# Required Libraries

import numpy as np
import pandas as pd

# %%
diabetes = pd.read_csv('Datasets/diabetes.csv')

movies = pd.read_csv('Datasets/movies.csv')

ipl = pd.read_csv('Datasets/ipl-matches.csv')

runs = pd.read_csv('Datasets/batsman_runs_ipl.csv')

# %% [markdown]
# #### **1 ) astype( )**

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# astype help us to change the data type of the column

ipl['ID'] = ipl['ID'].astype('int32')

ipl.info()  # you can the Id column's dtype is 'int32'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %% [markdown]
# #### **2 ) value_counts( )**

# %%
marks = pd.DataFrame([
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,70,14],
    [80,70,14]
],columns=['iq','marks','package'])

marks
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14
# 4   80     70       14

# %%
# Value_counts : Tell the frequency count of unique items ( applicable on both Series and DataFrame)

marks.value_counts()
# Out:
# iq   marks  package
# 80   70     14         2
# 90   70     7          1
# 100  80     10         1
# 120  100    14         1
# Name: count, dtype: int64

# %%
ipl.sample(3)
# Out:
#           ID       City        Date   Season MatchNumber                Team1  \
# 174  1216511  Abu Dhabi  2020-10-06  2020/21          20       Mumbai Indians
# 711   501262     Mumbai  2011-05-19     2011          65        Pune Warriors
# 787   419153    Chennai  2010-04-13  2009/10          48  Chennai Super Kings
#
#                      Team2                            Venue  \
# 174       Rajasthan Royals             Sheikh Zayed Stadium
# 711  Kolkata Knight Riders       Dr DY Patil Sports Academy
# 787  Kolkata Knight Riders  MA Chidambaram Stadium, Chepauk
#
#                 TossWinner TossDecision SuperOver            WinningTeam  \
# 174         Mumbai Indians          bat         N         Mumbai Indians
# 711  Kolkata Knight Riders        field         N  Kolkata Knight Riders
# 787  Kolkata Knight Riders          bat         N    Chennai Super Kings
#
#        WonBy  Margin method Player_of_Match  \
# 174     Runs    57.0    NaN        SA Yadav
# ...

# %%
# Example : Which player has the won most player of the match --> in Finals and Qualifiers

special_matches = ipl[~ipl['MatchNumber'].str.isdigit()]  # 

special_matches['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# JJ Bumrah            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# A Kumble             2
# YK Pathan            2
# SR Watson            2
# HH Pandya            1
# RM Patidar           1
# JC Buttler           1
# RR Pant              1
# KS Williamson        1
# MP Stoinis           1
# TA Boult             1
# SP Narine            1
# RD Gaikwad           1
# VR Iyer              1
# DA Miller            1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# BCJ Cutting          1
# KH Pandya            1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# RG Sharma            1
# A Nehra              1
# DA Warner            1
# MC Henriques         1
# Harbhajan Singh      1
# BJ Hodge             1
# UT Yadav             1
# V Sehwag             1
# MS Bisla             1
# MEK Hussey           1
# ...

# %%
# Example : Toss Decision in % 

# One Way 

ipl['TossDecision'].value_counts(normalize=True)
# Out:
# TossDecision
# field    0.630526
# bat      0.369474
# Name: proportion, dtype: float64

# %%
# Another way

ipl['TossDecision'].value_counts().plot(kind='pie',)
# Out:
# <Axes: ylabel='count'>

# %%
# Example : How many matches each team has played

(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %% [markdown]
# #### **3 ) sort_values( )**

# %%
movies.sample(3)
# Out:
#                                   title_x    imdb_id  \
# 963                          Bal Ganesh 2  tt8823390
# 624  Once Upon ay Time in Mumbai Dobaara!  tt1891884
# 410                           P Se PM Tak  tt3255586
#
#                                            poster_path  \
# 963  https://upload.wikimedia.org/wikipedia/en/thum...
# 624  https://upload.wikimedia.org/wikipedia/en/thum...
# 410                                                NaN
#
#                                              wiki_link  \
# 963         https://en.wikipedia.org/wiki/Bal_Ganesh_2
# 624  https://en.wikipedia.org/wiki/Once_Upon_Ay_Tim...
# 410          https://en.wikipedia.org/wiki/P_Se_PM_Tak
#
#                                  title_y                       original_title  \
# 963                         Bal Ganesh 2                         Bal Ganesh 2
# 624  Once Upon a Time in Mumbai Dobaara!  Once Upon a Time in Mumbai Dobaara!
# ...

# %% [markdown]
# **On sorting on basis of single column**

# %%
# sorts the values , by default in acesending order (applicable on both Series and DataFrame)

# On sorting on basis of single column

movies.sort_values('title_x',ascending=False)
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
students = pd.DataFrame(
    {
        'name':['nitish','ankit','rupesh',np.nan,'mrityunjay',np.nan,'rishabh',np.nan,'aditya',np.nan],
        'college':['bit','iit','vit',np.nan,np.nan,'vlsi','ssit',np.nan,np.nan,'git'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]

    }
)

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
#  What happens , when sort values in presence of nan values

students.sort_values('name')
# Out:
#          name college branch   cgpa  package
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN

# %%
# To bring the nan values on top 


students.sort_values('name',na_position='first')

#  To make sorting operations , we can use inplace = True
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %% [markdown]
# **On sorting on basis of multiple columns**

# %%
# Sort the release moive year and also in alphabetically 

movies.sort_values(['year_of_release','title_x'])[['title_x','year_of_release']]
# Out:
#                                title_x  year_of_release
# 1575                       Aalavandhan             2001
# 1576  Aamdani Atthanni Kharcha Rupaiya             2001
# 1577                Aashiq (2001 film)             2001
# 1579               Ajnabee (2001 film)             2001
# 1578                   Aks (2001 film)             2001
# ...                                ...              ...
# 64                         Ujda Chaman             2019
# 0             Uri: The Surgical Strike             2019
# 3                      Why Cheat India             2019
# 60                  Yaaram (2019 film)             2019
# 73                  Yeh Saali Aashiqui             2019
#
# [1629 rows x 2 columns]

# %%
# One acsending and other decsending

movies.sort_values(['year_of_release','title_x'],ascending=[True,False])[['title_x','year_of_release']]
# Out:
#                                    title_x  year_of_release
# 1623                              Zubeidaa             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar             2001
# 1620              Yeh Raaste Hain Pyaar Ke             2001
# 1573                   Yaadein (2001 film)             2001
# ...                                    ...              ...
# 37                       Article 15 (film)             2019
# 46                           Arjun Patiala             2019
# 10                                  Amavas             2019
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?             2019
# 21                                22 Yards             2019
#
# [1629 rows x 2 columns]

# %% [markdown]
# #### **4 ) rank( )**

# %%
runs = pd.read_csv('Datasets/batsman_runs_ipl.csv')
runs.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
# Rank : The rank() function in Pandas assigns ranks to elements in a Series or DataFrame, 
# typically used to assign ordinal rankings to numeric data

# Applicable on only Series

runs['batsman_rank'] = runs['batsman_run'].rank(ascending=False)
runs.sort_values('batsman_rank')

# Note : Same values = same rank
# Out:
#              batter  batsman_run  batsman_rank
# 569         V Kohli         6634           1.0
# 462        S Dhawan         6244           2.0
# 130       DA Warner         5883           3.0
# 430       RG Sharma         5881           4.0
# 493        SK Raina         5536           5.0
# ..              ...          ...           ...
# 570  V Pratap Singh            0         594.0
# 63     Abdur Razzak            0         594.0
# 562          U Kaul            0         594.0
# 65       Akash Deep            0         594.0
# 57           AS Roy            0         594.0
#
# [605 rows x 3 columns]

# %% [markdown]
# #### **5 ) sort_index( )**

# %%
marks = {
    'maths': 95,
    'english':75,
    'science':90,
    'hindi':99
}

marks_series = pd.Series(marks)
marks_series
# Out:
# maths      95
# english    75
# science    90
# hindi      99
# dtype: int64

# %%
# This sorts the index (Applicable on both Series and DataFrame)

# For Series 

marks_series.sort_index()
# Out:
# english    75
# hindi      99
# maths      95
# science    90
# dtype: int64

# %%
marks_series.sort_index(ascending=False)
# Out:
# science    90
# maths      95
# hindi      99
# english    75
# dtype: int64

# %%
# For DataFrame

movies.sort_index(ascending=False).head()
# Out:
#                     title_x     imdb_id  \
# 1628               Humsafar   tt2403201
# 1627                  Daaka  tt10833860
# 1626        Sabse Bada Sukh   tt0069204
# 1625   Yeh Zindagi Ka Safar   tt0298607
# 1624  Tera Mera Saath Rahen   tt0301250
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
#
#                                               wiki_link  \
# 1628             https://en.wikipedia.org/wiki/Humsafar
# 1627                https://en.wikipedia.org/wiki/Daaka
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...
# 1624  https://en.wikipedia.org/wiki/Tera_Mera_Saath_...
#
# ...

# %% [markdown]
# #### **6 ) set_index( )**

# %%
# Using this we can are own index (applicable on both Series and DataFrame)

runs.sample(3)
# Out:
#         batter  batsman_run  batsman_rank
# 423  RA Jadeja         2502          31.0
# 419   R Shukla           19         431.5
# 484  SB Styris          131         237.0

# %%
runs.set_index('batter',inplace=True)

# Make it permanent changes we use inplace = True

# %%
runs
# Out:
#                 batsman_run  batsman_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %% [markdown]
# #### **7 ) reset_index( )**

# %%
# Simple it reset the index  (Applicable on both Series and DataFrame)

runs.reset_index()
# Out:
#              batter  batsman_run  batsman_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
runs
# Out:
#                 batsman_run  batsman_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
# How to replace existing index without loosing column 

runs.reset_index().set_index('batsman_rank')
# Out:
#                       batter  batsman_run
# batsman_rank
# 166.5         A Ashish Reddy          280
# 226.0               A Badoni          161
# 535.0             A Chandila            4
# 329.0               A Chopra           53
# 402.5            A Choudhary           25
# ...                      ...          ...
# 594.0             Yash Dayal            0
# 343.0          Yashpal Singh           47
# 547.5            Younis Khan            3
# 27.0            Yuvraj Singh         2754
# 256.0                 Z Khan          117
#
# [605 rows x 2 columns]

# %%
# On Series , reset_index 

marks_series
# Out:
# maths      95
# english    75
# science    90
# hindi      99
# dtype: int64

# %%
marks_series.reset_index()  # And it is DataFrame , so we can use it to convert Series --> DataFrame
# Out:
#      index   0
# 0    maths  95
# 1  english  75
# 2  science  90
# 3    hindi  99

# %% [markdown]
# #### **8 ) rename( )**

# %%
# Rename the columns in DataFrame (applicable on DataFrame)

movies.sample()
# Out:
#                 title_x    imdb_id  \
# 1166  Fanaa (2006 film)  tt0439662
#
#                                             poster_path  \
# 1166  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link title_y original_title  \
# 1166  https://en.wikipedia.org/wiki/Fanaa_(2006_film)   Fanaa          Fanaa
#
#       is_adult  year_of_release runtime         genres  imdb_rating  \
# 1166         0             2006     168  Drama|Romance          7.2
#
#       imdb_votes                                              story  \
# 1166       29219  Choices - to choose between right or wrong is ...
#
#                                                 summary               tagline  \
# 1166  A sweet blind girl Zooni meets a flirty Rehan....  Destroyed in love...
#
#                                                  actors  \
# 1166  Aamir Khan|Kajol|Rishi Kapoor|Tabu|Kiron Kher|...
#
#             wins_nominations         release_date
# ...

# %%
movies.rename(columns={'imdb_id':'imdb'})
# Out:
#                                    title_x        imdb  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# By using rename , we can also rename index

movies.set_index('title_x').rename(index={'Uri: The Surgical Strike':'Uri','Battalion 609':'Battalion'})
# Out:
#                                          imdb_id  \
# title_x
# Uri                                    tt8291224
# Battalion                              tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster_path  \
# title_x
# Uri                                   https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion                                                                           NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# **9 ) unique( )**

# %%
# Give us unique values (applicable for Series)

temp = pd.Series([1,1,2,2,2,3,3,3,4,4,5,5,6,6])

temp.unique()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
ipl['Season'].unique()  # It consider nan value as unique
# Out:
# array(['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08'],
#       dtype=object)

# %%
len(ipl['Season'].unique())
# Out:
# 15

# %% [markdown]
# **10 ) nunique( )**

# %%
# Give us noumber of unique values  --> but it don't count nan

temp.nunique()
# Out:
# 6

# %% [markdown]
# **11 ) isnull( )**

# %%
# Tell is there any missing values  (applicable on Series and DataFrame)

students[students['name'].isnull()]
# Out:
#   name college branch  cgpa  package
# 3  NaN     NaN    NaN   NaN      NaN
# 5  NaN    vlsi     ce   9.0      7.0
# 7  NaN     NaN    cse  10.0      9.0
# 9  NaN     git    NaN   NaN      NaN

# %%
students.isnull()
# Out:
#     name  college  branch   cgpa  package
# 0  False    False   False  False    False
# 1  False    False   False  False    False
# 2  False    False   False  False    False
# 3   True     True    True   True     True
# 4  False     True   False  False    False
# 5   True    False   False  False    False
# 6  False    False   False  False    False
# 7   True     True   False  False    False
# 8  False     True   False  False     True
# 9   True    False    True   True     True

# %% [markdown]
# **11 ) notnull( )**

# %%
# It tell about non missing values  (works on series and DataFrame both)
students.notnull()
# Out:
#     name  college  branch   cgpa  package
# 0   True     True    True   True     True
# 1   True     True    True   True     True
# 2   True     True    True   True     True
# 3  False    False   False  False    False
# 4   True    False    True   True     True
# 5  False     True    True   True     True
# 6   True     True    True   True     True
# 7  False    False    True   True     True
# 8   True    False    True   True    False
# 9  False     True   False  False    False

# %% [markdown]
# **12 ) hasnans( )**

# %%
# Tells is there any nan values (work on Series)

students['name'].hasnans
# Out:
# True

# %% [markdown]
# **13 ) dropna( )**

# %%
# Delete the missing values or rows  (Applicable on both Series and DataFrame)

students['name'].dropna()
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 4    mrityunjay
# 6       rishabh
# 8        aditya
# Name: name, dtype: object

# %%
students.dropna()  # Even if a single column have nan value , then it removes whole row
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0

# %%
# Drop the missing values we can control the behavior

students.dropna(how='all')
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
# Removing the that row which having the missing values in name column

students.dropna(subset=['name'])
# Out:
#          name college branch  cgpa  package
# 0      nitish     bit    eee  6.66      4.0
# 1       ankit     iit     it  8.25      5.0
# 2      rupesh     vit    cse  6.41      6.0
# 4  mrityunjay     NaN     me  5.60      6.0
# 6     rishabh    ssit    civ  7.40      8.0
# 8      aditya     NaN    bio  7.40      NaN

# %%
# Removing the that row which having the missing values in name column

students.dropna(subset=['name','college'])


# For permanent change use inplace = True
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0

# %% [markdown]
# **14 ) fillna( )**

# %%
# Fills the missing value with given value (Applicable on both Series and DataFrame)

students['name'].fillna('unknown').hasnans
# Out:
# False

# %%
# On DataFrame

students.fillna('missing')
# Out:
#          name  college   branch     cgpa  package
# 0      nitish      bit      eee     6.66      4.0
# 1       ankit      iit       it     8.25      5.0
# 2      rupesh      vit      cse     6.41      6.0
# 3     missing  missing  missing  missing  missing
# 4  mrityunjay  missing       me      5.6      6.0
# 5     missing     vlsi       ce      9.0      7.0
# 6     rishabh     ssit      civ      7.4      8.0
# 7     missing  missing      cse     10.0      9.0
# 8      aditya  missing      bio      7.4  missing
# 9     missing      git  missing  missing  missing

# %%
# Filling values in package column

mean_val = students['package'].mean()

students['package'].fillna(mean_val)
# Out:
# 0    4.000000
# 1    5.000000
# 2    6.000000
# 3    6.428571
# 4    6.000000
# 5    7.000000
# 6    8.000000
# 7    9.000000
# 8    6.428571
# 9    6.428571
# Name: package, dtype: float64

# %%
students['name'].ffill()
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3        rupesh
# 4    mrityunjay
# 5    mrityunjay
# 6       rishabh
# 7       rishabh
# 8        aditya
# 9        aditya
# Name: name, dtype: object

# %%
students['name'].bfill()
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3    mrityunjay
# 4    mrityunjay
# 5       rishabh
# 6       rishabh
# 7        aditya
# 8        aditya
# 9           NaN
# Name: name, dtype: object

# %% [markdown]
# **15 ) drop_duplicates( )**

# %%
stud_dict = {
    'iq' : [100,80,120,95,90,90],
    'marks' : [95,70,99,85,70,70] ,
    'package' : [20,10,30,10,15,15] 
}

stud = pd.DataFrame(stud_dict)
stud
# Out:
#     iq  marks  package
# 0  100     95       20
# 1   80     70       10
# 2  120     99       30
# 3   95     85       10
# 4   90     70       15
# 5   90     70       15

# %%
stud.drop_duplicates()
# Out:
#     iq  marks  package
# 0  100     95       20
# 1   80     70       10
# 2  120     99       30
# 3   95     85       10
# 4   90     70       15

# %%
stud.drop_duplicates(keep='last')  # By default it is 'first'
# Out:
#     iq  marks  package
# 0  100     95       20
# 1   80     70       10
# 2  120     99       30
# 3   95     85       10
# 5   90     70       15

# %%
# Example : Find the last match played by vk in delhi

ipl.sample(3)
# Out:
#           ID       City        Date Season MatchNumber  \
# 308  1136566     Jaipur  2018-04-11   2018           6
# 646   548363    Kolkata  2012-05-12   2012          58
# 477   829737  Bangalore  2015-04-19   2015          16
#
#                            Team1             Team2                   Venue  \
# 308             Rajasthan Royals  Delhi Daredevils  Sawai Mansingh Stadium
# 646        Kolkata Knight Riders    Mumbai Indians            Eden Gardens
# 477  Royal Challengers Bangalore    Mumbai Indians   M Chinnaswamy Stadium
#
#                       TossWinner TossDecision SuperOver       WinningTeam  \
# 308             Delhi Daredevils        field         N  Rajasthan Royals
# 646               Mumbai Indians          bat         N    Mumbai Indians
# 477  Royal Challengers Bangalore        field         N    Mumbai Indians
#
#     WonBy  Margin method  Player_of_Match  \
# 308  Runs    10.0    D/L        SV Samson
# 646  Runs    27.0    NaN        RG Sharma
# ...

# %%
ipl['All_player'] = ipl['Team1Players'] + ipl['Team2Players']

ipl.sample()
# Out:
#           ID       City        Date Season MatchNumber  \
# 368  1082595  Bengaluru  2017-04-08   2017           5
#
#                            Team1             Team2                  Venue  \
# 368  Royal Challengers Bangalore  Delhi Daredevils  M.Chinnaswamy Stadium
#
#                       TossWinner TossDecision  ...  \
# 368  Royal Challengers Bangalore          bat  ...
#
#                      WinningTeam WonBy Margin  method Player_of_Match  \
# 368  Royal Challengers Bangalore  Runs   15.0     NaN       KM Jadhav
#
#                                           Team1Players  \
# 368  ['CH Gayle', 'SR Watson', 'Mandeep Singh', 'KM...
#
#                                           Team2Players Umpire1    Umpire2  \
# 368  ['AP Tare', 'SW Billings', 'KK Nair', 'SV Sams...  S Ravi  VK Sharma
#
#                                             All_player
# 368  ['CH Gayle', 'SR Watson', 'Mandeep Singh', 'KM...
#
# [1 rows x 21 columns]

# %%
def is_vk_played(player_list):
    return 'V Kohli' in player_list

# %%
ipl['did_vk_played'] = ipl['All_player'].apply(is_vk_played)
ipl['did_vk_played']
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 945    False
# 946     True
# 947    False
# 948    False
# 949     True
# Name: did_vk_played, Length: 950, dtype: bool

# %%
ipl[(ipl['City'] == 'Delhi') & (ipl['did_vk_played'] == True)].drop_duplicates(subset=['City','did_vk_played'],keep='first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... WonBy Margin method  Player_of_Match  \
# 208          bat  ...  Runs   16.0    NaN         S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                         All_player  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     did_vk_played
# 208          True
#
# [1 rows x 22 columns]

# %% [markdown]
# **15 ) drop( )**

# %%
# It help us to delete the column as well as rows  (applicable on both Series and DataFrame)

temp = pd.Series([10,45,6,78,34,56])
temp
# Out:
# 0    10
# 1    45
# 2     6
# 3    78
# 4    34
# 5    56
# dtype: int64

# %%
temp.drop(index=[0,5])
# Out:
# 1    45
# 2     6
# 3    78
# 4    34
# dtype: int64

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students.drop(columns=['college','cgpa'])
# Out:
#          name branch  package
# 0      nitish    eee      4.0
# 1       ankit     it      5.0
# 2      rupesh    cse      6.0
# 3         NaN    NaN      NaN
# 4  mrityunjay     me      6.0
# 5         NaN     ce      7.0
# 6     rishabh    civ      8.0
# 7         NaN    cse      9.0
# 8      aditya    bio      NaN
# 9         NaN    NaN      NaN

# %%
students.drop(index=[3,9])
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN

# %% [markdown]
# **16 ) apply( )**

# %%
# .apply() function is used to apply a function to each row or 
# column of a DataFrame, or to each element

temp = pd.Series([10,20,30,40,50])

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
temp.apply(sigmoid)
# Out:
# 0    0.999955
# 1    1.000000
# 2    1.000000
# 3    1.000000
# 4    1.000000
# dtype: float64

# %%
points_df = pd.DataFrame(
    {
        '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
        '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    }
)

points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (0, 0)    (2, 2)
# 3  (-10, 1)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
# Euclidean distance 

def euclidean(row):
    
    pt_A = row['1st point']
    pt_B = row['2nd point']
    
    return ((pt_A[0] - pt_B[0])**2 + (pt_A[1] - pt_B[1])**2)**0.5

# %%
points_df['distance'] = points_df.apply(euclidean,axis=1)

# %%
points_df
# Out:
#   1st point 2nd point   distance
# 0    (3, 4)   (-3, 4)   6.000000
# 1   (-6, 5)    (0, 0)   7.810250
# 2    (0, 0)    (2, 2)   2.828427
# 3  (-10, 1)  (10, 10)  21.931712
# 4    (4, 5)    (1, 1)   5.000000
