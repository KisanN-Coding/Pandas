# %% [markdown]
# ## **Pandas DataFrame**
#
# **A DataFrame in Pandas is a two-dimensional labeled data structure, similar to a table in a database or an Excel spreadsheet**
#
# **Key Points :**
#
# - It consists of rows and columns
#
# - Each column can hold data of different types (integers, floats, strings, etc.)
#
# - Think of it as a dictionary of Series, where each key is a column name
#
# **Features :**
#
# - Easy to filter rows and columns
#
# - Allows reading from and writing to files like CSV, Excel, SQL, etc
#
# - Great for data cleaning, analysis, and manipulation

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### **Creating DataFrame**

# %% [markdown]
# **Using Lists**

# %%
students_data = [
    [100,90,12],
    [80,60,5],
    [120,98,20],
    [200,100,50]
]

# %%
# Create dataframe using list

pd.DataFrame(students_data,columns=['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  100     90       12
# 1   80     60        5
# 2  120     98       20
# 3  200    100       50

# %% [markdown]
# **Using Dictionary**

# %%
stud_dict = {
    'iq' : [100,80,120,95],
    'marks' : [95,70,99,85] ,
    'package' : [20,10,30,15] 
}

# %%
# Creating dataframe using dictionary

students = pd.DataFrame(stud_dict)
students
# Out:
#     iq  marks  package
# 0  100     95       20
# 1   80     70       10
# 2  120     99       30
# 3   95     85       15

# %% [markdown]
# **Using read_csv**

# %%
# ipl runs data

runs = pd.read_csv('Datasets/batsman_runs_ipl.csv') 

runs.sample(5)
# Out:
#             batter  batsman_run
# 62     Abdul Samad          228
# 543    T Natarajan            3
# 571       V Sehwag         2728
# 115  CK Langeveldt            8
# 109      CH Morris          618

# %%
# ipl matches data

ipl = pd.read_csv('Datasets/ipl-matches.csv')
ipl.sample(5)
# Out:
#           ID       City        Date   Season MatchNumber  \
# 578   598047     Jaipur  2013-05-05     2013          50
# 480   829729     Mumbai  2015-04-17     2015          12
# 155  1216494  Abu Dhabi  2020-10-21  2020/21          39
# 592   598032     Jaipur  2013-04-27     2013          36
# 583   598041    Chennai  2013-05-02     2013          45
#
#                      Team1                        Team2  \
# 578       Rajasthan Royals                Pune Warriors
# 480         Mumbai Indians          Chennai Super Kings
# 155  Kolkata Knight Riders  Royal Challengers Bangalore
# 592       Rajasthan Royals          Sunrisers Hyderabad
# 583    Chennai Super Kings              Kings XI Punjab
#
#                                Venue             TossWinner TossDecision  \
# 578           Sawai Mansingh Stadium          Pune Warriors          bat
# 480                 Wankhede Stadium         Mumbai Indians          bat
# 155             Sheikh Zayed Stadium  Kolkata Knight Riders          bat
# 592           Sawai Mansingh Stadium    Sunrisers Hyderabad          bat
# 583  MA Chidambaram Stadium, Chepauk    Chennai Super Kings          bat
#
#     SuperOver                  WinningTeam    WonBy  Margin method  \
# 578         N             Rajasthan Royals  Wickets     5.0    NaN
# 480         N          Chennai Super Kings  Wickets     6.0    NaN
# 155         N  Royal Challengers Bangalore  Wickets     8.0    NaN
# 592         N             Rajasthan Royals  Wickets     8.0    NaN
# 583         N          Chennai Super Kings     Runs    15.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 578       AM Rahane  ['R Dravid', 'AM Rahane', 'SR Watson', 'BJ Hod...
# 480         A Nehra  ['LMP Simmons', 'PA Patel', 'CJ Anderson', 'RG...
# 155  Mohammed Siraj  ['Shubman Gill', 'RA Tripathi', 'N Rana', 'T B...
# 592     JP Faulkner  ['R Dravid', 'AM Rahane', 'SR Watson', 'STR Bi...
# 583        SK Raina  ['WP Saha', 'MEK Hussey', 'SK Raina', 'MS Dhon...
#
#                                           Team2Players        Umpire1  \
# 578  ['RV Uthappa', 'AJ Finch', 'Yuvraj Singh', 'MR...  C Shamshuddin
# 480  ['DR Smith', 'BB McCullum', 'SK Raina', 'F du ...   AK Chaudhary
# 155  ['D Padikkal', 'AJ Finch', 'Gurkeerat Singh', ...      VK Sharma
# 592  ['PA Reddy', 'S Dhawan', 'KC Sangakkara', 'GH ...    VA Kulkarni
# 583  ['LA Pomersbach', 'Mandeep Singh', 'SE Marsh',...      M Erasmus
#
#          Umpire2
# 578    RJ Tucker
# 480    M Erasmus
# 155       S Ravi
# 592    K Srinath
# 583  VA Kulkarni

# %%
# Movies Data
movies = pd.read_csv('Datasets/movies.csv')
movies.sample(5)
# Out:
#                           title_x    imdb_id  \
# 452                      Ranbanka  tt5151622
# 1402           Border (1997 film)  tt0347416
# 1482  Talaash: The Hunt Begins...  tt0338477
# 813                     Desi Boyz  tt1985981
# 631               John Day (film)  tt2699840
#
#                                             poster_path  \
# 452   https://upload.wikimedia.org/wikipedia/en/thum...
# 1402  https://upload.wikimedia.org/wikipedia/en/thum...
# 1482  https://upload.wikimedia.org/wikipedia/en/thum...
# 813   https://upload.wikimedia.org/wikipedia/en/thum...
# 631   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 452              https://en.wikipedia.org/wiki/Ranbanka
# 1402   https://en.wikipedia.org/wiki/Border_(1997_film)
# 1482  https://en.wikipedia.org/wiki/Talaash:_The_Hun...
# 813             https://en.wikipedia.org/wiki/Desi_Boyz
# 631       https://en.wikipedia.org/wiki/John_Day_(film)
#
#                           title_y               original_title  is_adult  \
# 452                      Ranbanka                     Ranbanka         0
# 1402                  LOC: Kargil                  LOC: Kargil         0
# 1482  Talaash: The Hunt Begins...  Talaash: The Hunt Begins...         0
# 813                     Desi Boyz                    Desi Boyz         0
# 631                      John Day                     John Day         0
#
#       year_of_release runtime                genres  imdb_rating  imdb_votes  \
# 452              2015      98                Action          3.7         118
# 1402             2003     255     Drama|History|War          5.1        2284
# 1482             2003     153  Action|Drama|Mystery          4.7        1292
# 813              2011     122          Comedy|Drama          5.7       12089
# 631              2013     138                 Drama          5.7         735
#
#                                                   story  \
# 452   Rahul  an engineer  tries his best to protect ...
# 1402  LOC KARGIL is the story of Indian soldiers fig...
# 1482  After receiving pardon from his jail term Babu...
# 813   Based in England  Nikhil Mathur is employed as...
# 631   John Day is a bank manager and lives with his ...
#
#                                                 summary  \
# 452   A non-violent engineer resorts to violence aft...
# 1402  Based on the real story during Kargil war foug...
# 1482                                             #NAME?
# 813   Two friends lose their jobs  then part bitterl...
# 631   John Day is a bank manager and lives with his ...
#
#                                                 tagline  \
# 452                                   A Film By Aryeman
# 1402  Heroes do not choose their destiny| destiny ch...
# 1482                                 The hunt begins...
# 813                                                 NaN
# 631                                                 NaN
#
#                                                  actors  \
# 452   Manish Paul|Ravi Kishan|Pooja Thakur|Rudra Kau...
# 1402  Sanjay Dutt|Ajay Devgn|Saif Ali Khan|Sunil She...
# 1482  Rakhee Gulzar|Akshay Kumar|Kareena Kapoor|Pooj...
# 813   Akshay Kumar|John Abraham|Deepika Padukone|Chi...
# 631   Naseeruddin Shah|Randeep Hooda|Elena Kazan|She...
#
#              wins_nominations               release_date
# 452                     1 win    6 November 2015 (India)
# 1402  2 wins & 10 nominations   12 December 2003 (India)
# 1482                      NaN     3 January 2003 (India)
# 813    2 wins & 6 nominations   25 November 2011 (India)
# 631                       NaN  13 September 2013 (India)

# %%
# Diabetes

diabetes = pd.read_csv('Datasets/diabetes.csv')
diabetes.sample(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 103            1       81             72             18       40  26.6
# 55             1       73             50             10        0  23.0
# 713            0      134             58             20      291  26.4
# 579            2      197             70             99        0  34.7
# 311            0      106             70             37      148  39.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 103                     0.283   24        0
# 55                      0.248   21        0
# 713                     0.352   21        0
# 579                     0.575   62        1
# 311                     0.605   22        0

# %% [markdown]
# #### **DataFrame Attributes and Methods**

# %% [markdown]
# ##### **Attributes**

# %% [markdown]
# **1 ) Shape**

# %%
movies.shape
# Out:
# (1629, 18)

# %%
runs.shape
# Out:
# (605, 2)

# %% [markdown]
# **2 ) Dtypes**

# %%
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %% [markdown]
# **3 ) Index**

# %%
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %% [markdown]
# **4 ) Columns**

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
runs.columns
# Out:
# Index(['batter', 'batsman_run'], dtype='object')

# %% [markdown]
# **5 ) Values**

# %%
students.values
# Out:
# array([[100,  95,  20],
#        [ 80,  70,  10],
#        [120,  99,  30],
#        [ 95,  85,  15]])

# %%
runs.values
# Out:
# array([['A Ashish Reddy', 280],
#        ['A Badoni', 161],
#        ['A Chandila', 4],
#        ...,
#        ['Younis Khan', 3],
#        ['Yuvraj Singh', 2754],
#        ['Z Khan', 117]], shape=(605, 2), dtype=object)

# %% [markdown]
# ##### **Methods**

# %% [markdown]
# **1 ) Head and Tail**

# %%
# head

ipl.head(10)  # first five
# Out:
#         ID         City        Date Season  MatchNumber  \
# 0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116       Mumbai  2022-05-22   2022           70
# 5  1304115       Mumbai  2022-05-21   2022           69
# 6  1304114       Mumbai  2022-05-20   2022           68
# 7  1304113       Mumbai  2022-05-19   2022           67
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          Team1                        Team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 2  Royal Challengers Bangalore         Lucknow Super Giants
# 3             Rajasthan Royals               Gujarat Titans
# 4          Sunrisers Hyderabad                 Punjab Kings
# 5               Delhi Capitals               Mumbai Indians
# 6          Chennai Super Kings             Rajasthan Royals
# 7               Gujarat Titans  Royal Challengers Bangalore
# 8         Lucknow Super Giants        Kolkata Knight Riders
# 9          Sunrisers Hyderabad               Mumbai Indians
#
#                                 Venue            TossWinner TossDecision  \
# 0    Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1    Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2               Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3               Eden Gardens, Kolkata        Gujarat Titans        field
# 4            Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
# 5            Wankhede Stadium, Mumbai        Mumbai Indians        field
# 6           Brabourne Stadium, Mumbai   Chennai Super Kings          bat
# 7            Wankhede Stadium, Mumbai        Gujarat Titans          bat
# 8  Dr DY Patil Sports Academy, Mumbai  Lucknow Super Giants          bat
# 9            Wankhede Stadium, Mumbai        Mumbai Indians        field
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
# 5         N               Mumbai Indians  Wickets     5.0    NaN
# 6         N             Rajasthan Royals  Wickets     5.0    NaN
# 7         N  Royal Challengers Bangalore  Wickets     8.0    NaN
# 8         N         Lucknow Super Giants     Runs     2.0    NaN
# 9         N          Sunrisers Hyderabad     Runs     3.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# 5       JJ Bumrah  ['PP Shaw', 'DA Warner', 'MR Marsh', 'RR Pant'...
# 6        R Ashwin  ['RD Gaikwad', 'DP Conway', 'MM Ali', 'N Jagad...
# 7         V Kohli  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...
# 8       Q de Kock  ['Q de Kock', 'KL Rahul', 'E Lewis', 'DJ Hooda...
# 9     RA Tripathi  ['Abhishek Sharma', 'PK Garg', 'RA Tripathi', ...
#
#                                         Team2Players                Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...            CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...            CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...          J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...           BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...           AK Chaudhary
# 5  ['Ishan Kishan', 'RG Sharma', 'D Brevis', 'Til...            Nitin Menon
# 6  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...            CB Gaffaney
# 7  ['V Kohli', 'F du Plessis', 'GJ Maxwell', 'KD ...  KN Ananthapadmanabhan
# 8  ['VR Iyer', 'A Tomar', 'N Rana', 'SS Iyer', 'S...               R Pandit
# 9  ['RG Sharma', 'Ishan Kishan', 'DR Sams', 'Tila...            CB Gaffaney
#
#             Umpire2
# 0       Nitin Menon
# 1       Nitin Menon
# 2          MA Gough
# 3         VK Sharma
# 4     NA Patwardhan
# 5      Tapan Sharma
# 6     NA Patwardhan
# 7  GR Sadashiv Iyer
# 8          YC Barde
# 9          N Pandit

# %%
runs.tail(5)  # last five
# Out:
#             batter  batsman_run
# 600     Yash Dayal            0
# 601  Yashpal Singh           47
# 602    Younis Khan            3
# 603   Yuvraj Singh         2754
# 604         Z Khan          117

# %% [markdown]
# **2 ) Sample**

# %%
movies.sample(2)  # random 2 rows
# Out:
#           title_x    imdb_id  \
# 1310   Vidyaarthi  tt1483815
# 1590  Deewaanapan  tt0301179
#
#                                             poster_path  \
# 1310  https://upload.wikimedia.org/wikipedia/en/thum...
# 1590  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                       wiki_link  \
# 1310   https://en.wikipedia.org/wiki/Vidyaarthi
# 1590  https://en.wikipedia.org/wiki/Deewaanapan
#
#                                  title_y                      original_title  \
# 1310  Vidhyaarthi: The Power of Students  Vidhyaarthi: The Power of Students
# 1590                         Deewaanapan                         Deewaanapan
#
#       is_adult  year_of_release runtime          genres  imdb_rating  \
# 1310         0             2006     250          Action          5.0
# 1590         0             2001     153  Action|Romance          4.6
#
#       imdb_votes                                              story  \
# 1310           8  This story about underworld and crime. How can...
# 1590         378  Suraj Saxena (Arjun Rampal) lives in a remote ...
#
#                                                 summary  \
# 1310  This story about underworld and crime. How can...
# 1590  A rebel crosses swords with an influential ric...
#
#                     tagline  \
# 1310  The power of students
# 1590                    NaN
#
#                                                  actors  \
# 1310  Vikram Aditya|Akash Ajmera|Ishrat Ali|Rajesh B...
# 1590  Arjun Rampal|Dia Mirza|Vinod Khanna|Om Puri|Sm...
#
#            wins_nominations              release_date
# 1310                    NaN      18 June 2006 (India)
# 1590  1 win & 2 nominations  16 November 2001 (India)

# %% [markdown]
# **3 ) Info**

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
#  16  Team1Players     950 non-null    object
#  17  Team2Players     950 non-null    object
#  18  Umpire1          950 non-null    object
#  19  Umpire2          950 non-null    object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 148.6+ KB

# %% [markdown]
# **4 ) Describe**

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %% [markdown]
# **5 ) Isnull**

# %%
ipl.isnull().sum()   # missing values
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
ipl.isnull().mean()*100  # percentage of missing values
# Out:
# ID                  0.000000
# City                5.368421
# Date                0.000000
# Season              0.000000
# MatchNumber         0.000000
# Team1               0.000000
# Team2               0.000000
# Venue               0.000000
# TossWinner          0.000000
# TossDecision        0.000000
# SuperOver           0.421053
# WinningTeam         0.421053
# WonBy               0.000000
# Margin              1.894737
# method             98.000000
# Player_of_Match     0.421053
# Team1Players        0.000000
# Team2Players        0.000000
# Umpire1             0.000000
# Umpire2             0.000000
# dtype: float64

# %% [markdown]
# **6 ) Duplicated**

# %%
print(ipl.duplicated().sum())
# Out:
# 0

# %% [markdown]
# **7 ) Rename**

# %%
students.rename(columns={'package':'lpa'},inplace=True)
students
# Out:
#     iq  marks  lpa
# 0  100     95   20
# 1   80     70   10
# 2  120     99   30
# 3   95     85   15

# %% [markdown]
# #### **Maths Methods**

# %% [markdown]
# **1 ) Sum**

# %%
students
# Out:
#     iq  marks  lpa
# 0  100     95   20
# 1   80     70   10
# 2  120     99   30
# 3   95     85   15

# %%
students.sum()  # Default is column wise ( axis = 0)
# Out:
# iq       395
# marks    349
# lpa       75
# dtype: int64

# %%
students.sum(axis=1)  # Row wise ( axis = 1)
# Out:
# 0    215
# 1    160
# 2    249
# 3    195
# dtype: int64

# %% [markdown]
# **2 ) Mean**

# %%
students.mean()  # Column wise
# Out:
# iq       98.75
# marks    87.25
# lpa      18.75
# dtype: float64

# %%
students.mean(axis=1)
# Out:
# 0    71.666667
# 1    53.333333
# 2    83.000000
# 3    65.000000
# dtype: float64

# %% [markdown]
# **3 ) Min**

# %%
students.min()
# Out:
# iq       80
# marks    70
# lpa      10
# dtype: int64

# %%
students.min(axis=1)
# Out:
# 0    20
# 1    10
# 2    30
# 3    15
# dtype: int64

# %% [markdown]
# **4 ) Max**

# %%
students.max()
# Out:
# iq       120
# marks     99
# lpa       30
# dtype: int64

# %%
students.max(axis=1)
# Out:
# 0    100
# 1     80
# 2    120
# 3     95
# dtype: int64

# %% [markdown]
# **5 ) Median**

# %%
students.median()
# Out:
# iq       97.5
# marks    90.0
# lpa      17.5
# dtype: float64

# %%
students.median(axis=1)
# Out:
# 0    95.0
# 1    70.0
# 2    99.0
# 3    85.0
# dtype: float64

# %% [markdown]
# **6 ) Varaince**

# %%
students.var()
# Out:
# iq       272.916667
# marks    166.916667
# lpa       72.916667
# dtype: float64

# %%
students.var(axis=1)
# Out:
# 0    2008.333333
# 1    1433.333333
# 2    2217.000000
# 3    1900.000000
# dtype: float64

# %% [markdown]
# **7 ) Standard Deviation**

# %%
students.std()
# Out:
# iq       16.520190
# marks    12.919623
# lpa       8.539126
# dtype: float64

# %%
students.std(axis=1)
# Out:
# 0    44.814432
# 1    37.859389
# 2    47.085029
# 3    43.588989
# dtype: float64

# %% [markdown]
# #### **Selecting column from a DataFrame**

# %% [markdown]
# **Single column**

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
movies['title_x'].sample(5)
# Out:
# 436            Talvar (film)
# 291          Dear Dad (film)
# 973     Raat Gayi Baat Gayi?
# 403          Kaagaz Ke Fools
# 1401              LOC Kargil
# Name: title_x, dtype: object

# %%
type(movies['title_x'])  # It is a series
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Multiple Column**

# %%
movies[['title_x','imdb_rating','genres']] # (flows the order you provided for column)
# Out:
#                                    title_x  imdb_rating            genres
# 0                 Uri: The Surgical Strike          8.4  Action|Drama|War
# 1                            Battalion 609          4.1               War
# 2     The Accidental Prime Minister (film)          6.1   Biography|Drama
# 3                          Why Cheat India          6.0       Crime|Drama
# 4                          Evening Shadows          7.3             Drama
# ...                                    ...          ...               ...
# 1624                 Tera Mera Saath Rahen          4.9             Drama
# 1625                  Yeh Zindagi Ka Safar          3.0             Drama
# 1626                       Sabse Bada Sukh          6.1      Comedy|Drama
# 1627                                 Daaka          7.4            Action
# 1628                              Humsafar          9.0     Drama|Romance
#
# [1629 rows x 3 columns]

# %%
type(movies[['title_x','imdb_rating','genres']])  # its is a Dataframe
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### **Selecting rows from DataFrame**
#
# - **iloc : searches using index positions**
#
# - **loc : searches using index labels**

# %%
stud_data = {
    'name' : ['Kisan','Kisna','Shubham','Fake'],
    'iq' : [100,80,120,95],
    'marks' : [95,70,99,85] ,
    'package' : [20,10,30,15] 
}

# %%
stud_data = pd.DataFrame(stud_data)
stud_data.set_index('name',inplace=True)

# %%
stud_data
# Out:
#           iq  marks  package
# name
# Kisan    100     95       20
# Kisna     80     70       10
# Shubham  120     99       30
# Fake      95     85       15

# %% [markdown]
# ##### **iloc**

# %% [markdown]
# **Single row**

# %%
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
# 2             2019     112   Biography|Drama          6.1        5549
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
# 1  The story revolves around a cricket match betw...
# 2  Based on the memoir by Indian policy analyst S...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
# 1  The story of Battalion 609 revolves around a c...     NaN
# 2  Explores Manmohan Singh's tenure as the Prime ...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
# 1  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...              NaN
# 2  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...              NaN
#
#               release_date
# 0    11 January 2019 (USA)
# 1  11 January 2019 (India)
# 2    11 January 2019 (USA)

# %%
movies.iloc[1]
# Out:
# title_x                                                 Battalion 609
# imdb_id                                                     tt9472208
# poster_path                                                       NaN
# wiki_link                 https://en.wikipedia.org/wiki/Battalion_609
# title_y                                                 Battalion 609
# original_title                                          Battalion 609
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           131
# genres                                                            War
# imdb_rating                                                       4.1
# imdb_votes                                                         73
# story               The story revolves around a cricket match betw...
# summary             The story of Battalion 609 revolves around a c...
# tagline                                                           NaN
# actors              Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# wins_nominations                                                  NaN
# release_date                                  11 January 2019 (India)
# Name: 1, dtype: object

# %% [markdown]
# **Multiple Rows**

# %%
movies.iloc[0:16:2]
# Out:
#                                  title_x    imdb_id  \
# 0               Uri: The Surgical Strike  tt8291224
# 2   The Accidental Prime Minister (film)  tt6986710
# 4                        Evening Shadows  tt6028796
# 6                          Fraud Saiyaan  tt5013008
# 8       Manikarnika: The Queen of Jhansi  tt6903440
# 10                                Amavas  tt8396186
# 12                             Hum Chaar  tt9319812
# 14                            Sonchiriya  tt8108200
#
#                                           poster_path  \
# 0   https://upload.wikimedia.org/wikipedia/en/thum...
# 2   https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                 NaN
# 6   https://upload.wikimedia.org/wikipedia/en/thum...
# 8   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
# 12  https://upload.wikimedia.org/wikipedia/en/thum...
# 14  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link  \
# 0   https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 2   https://en.wikipedia.org/wiki/The_Accidental_P...
# 4       https://en.wikipedia.org/wiki/Evening_Shadows
# 6         https://en.wikipedia.org/wiki/Fraud_Saiyaan
# 8   https://en.wikipedia.org/wiki/Manikarnika:_The...
# 10               https://en.wikipedia.org/wiki/Amavas
# 12            https://en.wikipedia.org/wiki/Hum_Chaar
# 14           https://en.wikipedia.org/wiki/Sonchiriya
#
#                              title_y                    original_title  \
# 0           Uri: The Surgical Strike          Uri: The Surgical Strike
# 2      The Accidental Prime Minister     The Accidental Prime Minister
# 4                    Evening Shadows                   Evening Shadows
# 6                      Fraud Saiyaan                     Fraud Saiyyan
# 8   Manikarnika: The Queen of Jhansi  Manikarnika: The Queen of Jhansi
# 10                            Amavas                            Amavas
# 12                         Hum chaar                         Hum chaar
# 14                        Sonchiriya                        Sonchiriya
#
#     is_adult  year_of_release runtime                  genres  imdb_rating  \
# 0          0             2019     138        Action|Drama|War          8.4
# 2          0             2019     112         Biography|Drama          6.1
# 4          0             2018     102                   Drama          7.3
# 6          0             2019     109            Comedy|Drama          4.2
# 8          0             2019     148  Action|Biography|Drama          6.5
# 10         0             2019     134         Horror|Thriller          2.8
# 12         0             2019     143                   Drama          5.6
# 14         0             2019     143      Action|Crime|Drama          7.5
#
#     imdb_votes                                              story  \
# 0        35112  Divided over five chapters  the film chronicle...
# 2         5549  Based on the memoir by Indian policy analyst S...
# 4          280  While gay rights and marriage equality has bee...
# 6          504  Fraud Saiyyan is the story of a con artist in ...
# 8         7361  Manikarnika born in Varanasi when Dixt a minis...
# 10         235  Far away from the bustle of the city  a young ...
# 12         183  The story of the film revolves around four col...
# 14        2322  This is the story of a group of rebels in Cham...
#
#                                               summary tagline  \
# 0   Indian army special forces execute a covert op...     NaN
# 2   Explores Manmohan Singh's tenure as the Prime ...     NaN
# 4   Under the 'Evening Shadows'  truth often plays...     NaN
# 6   Fraud Saiyyan is the story of a con artist in ...     NaN
# 8   Story of Rani Lakshmibai  one of the leading f...     NaN
# 10  The lives of a couple turn into a nightmare  a...     NaN
# 12  The story of the film revolves around four col...     NaN
# 14  Set in the Chambal valley  the film follows th...     NaN
#
#                                                actors        wins_nominations  \
# 0   Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...                  4 wins
# 2   Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...                     NaN
# 4   Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...  17 wins & 1 nomination
# 6   Arshad Warsi|Saurabh Shukla|Flora Saini|Sara L...                     NaN
# 8   Kangana Ranaut|Rimi Sen|Atul Kulkarni|Nalneesh...                     NaN
# 10  Ali Asgar|Vivan Bhatena|Nargis Fakhri|Sachiin ...                     NaN
# 12  Prit Kamani|Simran Sharma|Anshuman Malhotra|Tu...                     NaN
# 14  Sushant Singh Rajput|Bhumi Pednekar|Manoj Bajp...                     NaN
#
#                 release_date
# 0      11 January 2019 (USA)
# 2      11 January 2019 (USA)
# 4    11 January 2019 (India)
# 6    18 January 2019 (India)
# 8      25 January 2019 (USA)
# 10   8 February 2019 (India)
# 12  15 February 2019 (India)
# 14      1 March 2019 (India)

# %% [markdown]
# **Fancy Indexing**

# %%
movies.iloc[[1,10,15]]
# Out:
#               title_x    imdb_id  \
# 1       Battalion 609  tt9472208
# 10             Amavas  tt8396186
# 15  Badla (2019 film)  tt8130968
#
#                                           poster_path  \
# 1                                                 NaN
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
# 15  https://upload.wikimedia.org/wikipedia/en/0/0c...
#
#                                           wiki_link        title_y  \
# 1       https://en.wikipedia.org/wiki/Battalion_609  Battalion 609
# 10             https://en.wikipedia.org/wiki/Amavas         Amavas
# 15  https://en.wikipedia.org/wiki/Badla_(2019_film)          Badla
#
#    original_title  is_adult  year_of_release runtime               genres  \
# 1   Battalion 609         0             2019     131                  War
# 10         Amavas         0             2019     134      Horror|Thriller
# 15          Badla         0             2019     118  Crime|Drama|Mystery
#
#     imdb_rating  imdb_votes  \
# 1           4.1          73
# 10          2.8         235
# 15          7.9       15499
#
#                                                 story  \
# 1   The story revolves around a cricket match betw...
# 10  Far away from the bustle of the city  a young ...
# 15  Naina Sethi a successful entrepreneur finds he...
#
#                                               summary tagline  \
# 1   The story of Battalion 609 revolves around a c...     NaN
# 10  The lives of a couple turn into a nightmare  a...     NaN
# 15  A dynamic young entrepreneur finds herself loc...     NaN
#
#                                                actors wins_nominations  \
# 1   Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...              NaN
# 10  Ali Asgar|Vivan Bhatena|Nargis Fakhri|Sachiin ...              NaN
# 15  Amitabh Bachchan|Taapsee Pannu|Amrita Singh|An...            1 win
#
#                release_date
# 1   11 January 2019 (India)
# 10  8 February 2019 (India)
# 15     8 March 2019 (India)

# %% [markdown]
# ##### **loc**

# %%
stud_data
# Out:
#           iq  marks  package
# name
# Kisan    100     95       20
# Kisna     80     70       10
# Shubham  120     99       30
# Fake      95     85       15

# %%
stud_data.loc['Kisan']  # It is a series
# Out:
# iq         100
# marks       95
# package     20
# Name: Kisan, dtype: int64

# %%
stud_data.loc['Kisan':'Shubham']  # last one included
# Out:
#           iq  marks  package
# name
# Kisan    100     95       20
# Kisna     80     70       10
# Shubham  120     99       30

# %%
stud_data.loc['Kisan':'Shubham':2]  # Alternate rows
# Out:
#           iq  marks  package
# name
# Kisan    100     95       20
# Shubham  120     99       30

# %%
stud_data.loc[['Kisan','Fake']]
# Out:
#         iq  marks  package
# name
# Kisan  100     95       20
# Fake    95     85       15

# %%
# Here in stud_data I provide my own indexes as name but , still pandas internally have the default indexing 0 to 1
# So what i want say that , we can also apply iloc on this 

stud_data.iloc[0]
# Out:
# iq         100
# marks       95
# package     20
# Name: Kisan, dtype: int64

# %%
stud_data.iloc[0:3]
# Out:
#           iq  marks  package
# name
# Kisan    100     95       20
# Kisna     80     70       10
# Shubham  120     99       30

# %%
stud_data.iloc[[1,3,2]]
# Out:
#           iq  marks  package
# name
# Kisna     80     70       10
# Fake      95     85       15
# Shubham  120     99       30

# %% [markdown]
# #### **Selecting both Rows and Column**

# %%
movies.iloc[0:3,0:3]  # Using iloc
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:2,'title_x':'poster_path']   # Using loc
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# #### **Filtering a DataFrame**

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...  CB Gaffaney  Nitin Menon

# %%
# Example : Find all the final winners

new_df = ipl[ipl['MatchNumber'] == 'Final'] 

new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# in one line 

ipl[ipl['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# How many super over finishes have occured
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
# or 

ipl['SuperOver'].value_counts()
# Out:
# SuperOver
# N    932
# Y     14
# Name: count, dtype: int64

# %%
# Example : How many matches has csk won in kolkata

ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
# Example : Toss Winner is match winner in % 

(ipl[ipl['TossWinner'] == ipl['WinningTeam']]['WinningTeam'].shape[0] / ipl.shape[0]) * 100
# Out:
# 51.473684210526315

# %%
movies.sample(3)
# Out:
#                     title_x    imdb_id  \
# 1379        Rudraksh (film)  tt0366985
# 1508     Chor Machaaye Shor  tt0331216
# 888   Knock Out (2010 film)  tt1558578
#
#                                             poster_path  \
# 1379  https://upload.wikimedia.org/wikipedia/en/thum...
# 1508  https://upload.wikimedia.org/wikipedia/en/thum...
# 888   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link             title_y  \
# 1379      https://en.wikipedia.org/wiki/Rudraksh_(film)            Rudraksh
# 1508   https://en.wikipedia.org/wiki/Chor_Machaaye_Shor  Chor Machaaye Shor
# 888   https://en.wikipedia.org/wiki/Knock_Out_(2010_...           Knock Out
#
#           original_title  is_adult  year_of_release runtime  \
# 1379            Rudraksh         0             2004     143
# 1508  Chor Machaaye Shor         0             2002     145
# 888            Knock Out         0             2010     117
#
#                      genres  imdb_rating  imdb_votes  \
# 1379  Action|Fantasy|Sci-Fi          2.6        1020
# 1508    Action|Comedy|Crime          4.2        1003
# 888      Action|Crime|Drama          5.9        1857
#
#                                                   story  \
# 1379  Healing powers that science cannot explain and...
# 1508  Fortunately  before his arrest Shyam manages t...
# 888   While making a phone call from a phone booth i...
#
#                                                 summary               tagline  \
# 1379  Healing powers that science cannot explain and...  The power to possess
# 1508  Fortunately  before his arrest Shyam manages t...                   NaN
# 888   Hidden with a mysterious agenda  a sniper hold...                   NaN
#
#                                                  actors wins_nominations  \
# 1379  Sanjay Dutt|Bipasha Basu|Sunil Shetty|Isha Kop...              NaN
# 1508  Bobby Deol|Om Puri|Paresh Rawal|Shekhar Suman|...              NaN
# 888   Sanjay Dutt|Irrfan Khan|Kangana Ranaut|Gulshan...              NaN
#
#                   release_date
# 1379  13 February 2004 (India)
# 1508    23 August 2002 (India)
# 888    15 October 2010 (India)

# %%
# Example : Numbers of Movies with rating > 8 and votes > 10000

movies[(movies['imdb_rating'] > 8 ) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
movies['genres'].value_counts()
# Out:
# genres
# Drama                     162
# Comedy|Drama|Romance      101
# Comedy|Drama               88
# Drama|Romance              86
# Action|Crime|Drama         86
#                          ...
# Action|Musical|Romance      1
# Documentary|War             1
# Action|Crime|Horror         1
# Comedy|Fantasy              1
# Comedy|Musical|Mystery      1
# Name: count, Length: 205, dtype: int64

# %%
# Example : Action moives with rating > 7.5

mask1 = movies['genres'].str.split('|').apply(lambda x : 'Action' in x)
mask2 = movies['imdb_rating'] > 7.5

movies[mask1 & mask2].sample(5)
# Out:
#                       title_x    imdb_id  \
# 112   Bhavesh Joshi Superhero  tt6129302
# 982              Jodhaa Akbar  tt0449994
# 362         Bajrangi Bhaijaan  tt3863552
# 1607  Nayak (2001 Hindi film)  tt0291376
# 106                     Raazi  tt7098658
#
#                                             poster_path  \
# 112   https://upload.wikimedia.org/wikipedia/en/thum...
# 982   https://upload.wikimedia.org/wikipedia/en/thum...
# 362   https://upload.wikimedia.org/wikipedia/en/thum...
# 1607  https://upload.wikimedia.org/wikipedia/en/thum...
# 106   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 112   https://en.wikipedia.org/wiki/Bhavesh_Joshi_Su...
# 982          https://en.wikipedia.org/wiki/Jodhaa_Akbar
# 362     https://en.wikipedia.org/wiki/Bajrangi_Bhaijaan
# 1607  https://en.wikipedia.org/wiki/Nayak_(2001_Hind...
# 106                 https://en.wikipedia.org/wiki/Raazi
#
#                       title_y           original_title  is_adult  \
# 112   Bhavesh Joshi Superhero  Bhavesh Joshi Superhero         0
# 982              Jodhaa Akbar             Jodhaa Akbar         0
# 362         Bajrangi Bhaijaan        Bajrangi Bhaijaan         0
# 1607     Nayak: The Real Hero     Nayak: The Real Hero         0
# 106                     Raazi                    Raazi         0
#
#       year_of_release runtime                 genres  imdb_rating  imdb_votes  \
# 112              2018     154           Action|Drama          7.6        4928
# 982              2008     213   Action|Drama|History          7.6       27541
# 362              2015     163    Action|Comedy|Drama          8.0       65877
# 1607             2001     187  Action|Drama|Thriller          7.8       12522
# 106              2018     138  Action|Drama|Thriller          7.8       20289
#
#                                                   story  \
# 112   Bhavesh Joshi Superhero is an action film abou...
# 982   Jodhaa Akbar is a sixteenth century love story...
# 362   A little mute girl from a Pakistani village ge...
# 1607  Employed as a camera-man at a popular televisi...
# 106   Hidayat Khan is the son of an Indian freedom f...
#
#                                                 summary  \
# 112   The origin story of Bhavesh Joshi  an Indian s...
# 982   A sixteenth century love story about a marriag...
# 362   An Indian man with a magnanimous heart takes a...
# 1607  A man accepts a challenge by the chief ministe...
# 106   A Kashmiri woman agrees to marry a Pakistani a...
#
#                                        tagline  \
# 112   This year| justice will have a new name.
# 982                                        NaN
# 362                                        NaN
# 1607                           Fight the power
# 106                   An incredible true story
#
#                                                  actors  \
# 112   Harshvardhan Kapoor|Priyanshu Painyuli|Ashish ...
# 982   Hrithik Roshan|Aishwarya Rai Bachchan|Sonu Soo...
# 362   Salman Khan|Harshaali Malhotra|Nawazuddin Sidd...
# 1607  Anil Kapoor|Rani Mukerji|Amrish Puri|Johnny Le...
# 106   Alia Bhatt|Vicky Kaushal|Rajit Kapoor|Shishir ...
#
#               wins_nominations              release_date
# 112              2 nominations         1 June 2018 (USA)
# 982   32 wins & 21 nominations    15 February 2008 (USA)
# 362   25 wins & 13 nominations        17 July 2015 (USA)
# 1607             2 nominations  7 September 2001 (India)
# 106   21 wins & 26 nominations         11 May 2018 (USA)

# %%
# Second Way to do this is 

mask1 = movies['genres'].str.contains('Action')
mask2 = movies['imdb_rating'] > 7.5

movies[mask1 & mask2].sample(5)
# Out:
#                       title_x    imdb_id  \
# 362         Bajrangi Bhaijaan  tt3863552
# 219          Raag Desh (film)  tt6080746
# 1607  Nayak (2001 Hindi film)  tt0291376
# 41       Family of Thakurganj  tt8897986
# 112   Bhavesh Joshi Superhero  tt6129302
#
#                                             poster_path  \
# 362   https://upload.wikimedia.org/wikipedia/en/thum...
# 219   https://upload.wikimedia.org/wikipedia/en/thum...
# 1607  https://upload.wikimedia.org/wikipedia/en/thum...
# 41    https://upload.wikimedia.org/wikipedia/en/9/99...
# 112   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 362     https://en.wikipedia.org/wiki/Bajrangi_Bhaijaan
# 219              https://en.wikipedia.org/wiki/Raagdesh
# 1607  https://en.wikipedia.org/wiki/Nayak_(2001_Hind...
# 41    https://en.wikipedia.org/wiki/Family_of_Thakur...
# 112   https://en.wikipedia.org/wiki/Bhavesh_Joshi_Su...
#
#                       title_y           original_title  is_adult  \
# 362         Bajrangi Bhaijaan        Bajrangi Bhaijaan         0
# 219                 Raag Desh                Raag Desh         0
# 1607     Nayak: The Real Hero     Nayak: The Real Hero         0
# 41       Family of Thakurganj     Family of Thakurganj         0
# 112   Bhavesh Joshi Superhero  Bhavesh Joshi Superhero         0
#
#       year_of_release runtime                 genres  imdb_rating  imdb_votes  \
# 362              2015     163    Action|Comedy|Drama          8.0       65877
# 219              2017     135   Action|Drama|History          8.3         341
# 1607             2001     187  Action|Drama|Thriller          7.8       12522
# 41               2019     127           Action|Drama          9.4         895
# 112              2018     154           Action|Drama          7.6        4928
#
#                                                   story  \
# 362   A little mute girl from a Pakistani village ge...
# 219   A period film based on the historic 1945 India...
# 1607  Employed as a camera-man at a popular televisi...
# 41    The film is based on small town of North India...
# 112   Bhavesh Joshi Superhero is an action film abou...
#
#                                                 summary  \
# 362   An Indian man with a magnanimous heart takes a...
# 219   A period film based on the historic 1945 India...
# 1607  A man accepts a challenge by the chief ministe...
# 41    The film is based on small town of North India...
# 112   The origin story of Bhavesh Joshi  an Indian s...
#
#                                        tagline  \
# 362                                        NaN
# 219                                        NaN
# 1607                           Fight the power
# 41                                         NaN
# 112   This year| justice will have a new name.
#
#                                                  actors  \
# 362   Salman Khan|Harshaali Malhotra|Nawazuddin Sidd...
# 219   Kunal Kapoor|Amit Sadh|Mohit Marwah|Kenneth De...
# 1607  Anil Kapoor|Rani Mukerji|Amrish Puri|Johnny Le...
# 41    Jimmy Sheirgill|Mahie Gill|Nandish Singh|Prana...
# 112   Harshvardhan Kapoor|Priyanshu Painyuli|Ashish ...
#
#               wins_nominations              release_date
# 362   25 wins & 13 nominations        17 July 2015 (USA)
# 219                        NaN      28 July 2017 (India)
# 1607             2 nominations  7 September 2001 (India)
# 41                         NaN      19 July 2019 (India)
# 112              2 nominations         1 June 2018 (USA)

# %% [markdown]
# #### **Adding new columns**

# %% [markdown]
# **Completely new column**

# %%
# adding new column country

movies['Country'] = 'India'

# %%
movies.head()  # new column country is added
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
# 3                Why Cheat India                Why Cheat India         0
# 4                Evening Shadows                Evening Shadows         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
# 2             2019     112   Biography|Drama          6.1        5549
# 3             2019     121       Crime|Drama          6.0        1891
# 4             2018     102             Drama          7.3         280
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
# 1  The story revolves around a cricket match betw...
# 2  Based on the memoir by Indian policy analyst S...
# 3  The movie focuses on existing malpractices in ...
# 4  While gay rights and marriage equality has bee...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
# 1  The story of Battalion 609 revolves around a c...     NaN
# 2  Explores Manmohan Singh's tenure as the Prime ...     NaN
# 3  The movie focuses on existing malpractices in ...     NaN
# 4  Under the 'Evening Shadows'  truth often plays...     NaN
#
#                                               actors        wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...                  4 wins
# 1  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...                     NaN
# 2  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...                     NaN
# 3  Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...                     NaN
# 4  Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...  17 wins & 1 nomination
#
#               release_date Country
# 0    11 January 2019 (USA)   India
# 1  11 January 2019 (India)   India
# 2    11 January 2019 (USA)   India
# 3    18 January 2019 (USA)   India
# 4  11 January 2019 (India)   India

# %% [markdown]
# **New column from existing one**

# %%
# Using dropna because of missing value
movies.dropna(inplace=True)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 298 entries, 11 to 1623
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           298 non-null    object
#  1   imdb_id           298 non-null    object
#  2   poster_path       298 non-null    object
#  3   wiki_link         298 non-null    object
#  4   title_y           298 non-null    object
#  5   original_title    298 non-null    object
#  6   is_adult          298 non-null    int64
#  7   year_of_release   298 non-null    int64
#  8   runtime           298 non-null    object
#  9   genres            298 non-null    object
#  10  imdb_rating       298 non-null    float64
#  11  imdb_votes        298 non-null    int64
#  12  story             298 non-null    object
#  13  summary           298 non-null    object
#  14  tagline           298 non-null    object
#  15  actors            298 non-null    object
#  16  wins_nominations  298 non-null    object
#  17  release_date      298 non-null    object
#  18  Country           298 non-null    object
# dtypes: float64(1), int64(3), object(15)
# memory usage: 46.6+ KB

# %%
# Adding the column 'Lead_actor'

movies['Lead_actor'] = movies['actors'].str.split('|').apply(lambda x:x[0])

movies.head()
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
# 87            Aiyaary   tt6774212
# 96   Raid (2018 film)   tt7363076
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
# 87  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
# 87            https://en.wikipedia.org/wiki/Aiyaary        Aiyaary
# 96   https://en.wikipedia.org/wiki/Raid_(2018_film)           Raid
#
#    original_title  is_adult  year_of_release runtime                  genres  \
# 11      Gully Boy         0             2019     153             Drama|Music
# 34  Yeh Hai India         0             2017     128  Action|Adventure|Drama
# 37     Article 15         0             2019     130             Crime|Drama
# 87        Aiyaary         0             2018     157         Action|Thriller
# 96           Raid         0             2018     122      Action|Crime|Drama
#
#     imdb_rating  imdb_votes  \
# 11          8.2       22440
# 34          5.7         169
# 37          8.3       13417
# 87          5.2        3538
# 96          7.4       13159
#
#                                                 story  \
# 11  Gully Boy is a film about a 22-year-old boy "M...
# 34  Yeh Hai India  follows the story of a 25 years...
# 37  In the rural heartlands of India  an upright p...
# 87  General Gurinder Singh comes with a proposal t...
# 96  Set in the 80s in Uttar Pradesh  India  Raid i...
#
#                                               summary  \
# 11  A coming-of-age story based on the lives of st...
# 34  Yeh Hai India  follows the story of a 25 years...
# 37  In the rural heartlands of India  an upright p...
# 87  After finding out about an illegal arms deal  ...
# 96  A fearless income tax officer raids the mansio...
#
#                                    tagline  \
# 11                       Apna Time Aayega!
# 34                 A Film for Every Indian
# 37  Farq Bahut Kar Liya| Ab Farq Laayenge.
# 87                   The Ultimate Trickery
# 96     Heroes don't always come in uniform
#
#                                                actors        wins_nominations  \
# 11  Ranveer Singh|Alia Bhatt|Siddhant Chaturvedi|V...  6 wins & 3 nominations
# 34   Gavie Chahal|Mohan Agashe|Mohan Joshi|Lom Harsh|   2 wins & 1 nomination
# 37  Ayushmann Khurrana|Nassar|Manoj Pahwa|Kumud Mi...                   1 win
# 87  Sidharth Malhotra|Manoj Bajpayee|Rakul Preet S...            1 nomination
# 96  Ajay Devgn|Saurabh Shukla|Ileana D'Cruz|Amit S...  2 wins & 3 nominations
#
#               release_date Country          Lead_actor
# 11  14 February 2019 (USA)   India       Ranveer Singh
# 34     24 May 2019 (India)   India        Gavie Chahal
# 37      28 June 2019 (USA)   India  Ayushmann Khurrana
# 87  16 February 2018 (USA)   India   Sidharth Malhotra
# 96   16 March 2018 (India)   India          Ajay Devgn
